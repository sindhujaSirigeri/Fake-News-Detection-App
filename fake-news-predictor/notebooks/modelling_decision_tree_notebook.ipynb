# %% [markdown]
# Fitting a decision tree machine learning model involves once the data has been preprocessed.

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error, r2_score
from sklearn import tree
import matplotlib.pyplot as plt
import h5py
from sklearn.model_selection import cross_val_score
import joblib
import json
# Out:
# c:\Users\wware\AppData\Local\anaconda3\envs\fake-news-predictor\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# Load the training and testing datasets
with h5py.File('../data/splits/train_test_split.h5', 'r') as f:
    X_train = f['X_train'][:]
    X_test = f['X_test'][:]
    y_train = f['y_train'][:]
    y_test = f['y_test'][:]

print("Training and testing sets loaded successfully.")
# Out:
# Training and testing sets loaded successfully.

# %%
# Model Decision Tree, classification
model = DecisionTreeClassifier()

# %%
# Setting hyperparameters
params = {
    'max_depth': 5,  # limit the depth of the tree
    'min_samples_split': 10,  # min samples required to split an internal node
    'min_samples_leaf': 5,  # min samples required to be at a leaf node
    'criterion': 'gini'  # for classification, use 'mse' for regression
}

model.set_params(**params)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=5, min_samples_split=10)

# %%
# Train the Model
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=5, min_samples_split=10)

# %%
# Evaluate the Model
y_pred = model.predict(X_test)

# %%
# For classification
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9134475345030862
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      7010
#            1       0.91      0.93      0.92      7409
#
#     accuracy                           0.91     14419
#    macro avg       0.91      0.91      0.91     14419
# weighted avg       0.91      0.91      0.91     14419

# %%
# Save the decision tree model to an .h5 file using joblib
model_save_path = '../models/decision_tree_model.pkl'
joblib.dump(model, model_save_path)
print(f"Decision Tree model saved to {model_save_path}.")
# Out:
# Decision Tree model saved to ../models/decision_tree_model.pkl.

# %%
# Create a dictionary to store the metrics
metrics = {
    "accuracy": accuracy,
    "classification_report": classification_report_dict  # Already a dictionary
}

# Specify the path where the metrics will be saved
metrics_save_path = '../models/decision_tree_metrics.json'

# Save the metrics dictionary to a JSON file
with open(metrics_save_path, 'w') as f:
    json.dump(metrics, f)

print(f"Model performance metrics saved to {metrics_save_path}.")
# Out:
# Model performance metrics saved to ../models/decision_tree_metrics.json.
